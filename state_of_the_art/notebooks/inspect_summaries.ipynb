# %%
from tiny_data_wharehouse.data_wharehouse import DataWharehouse
tdw = DataWharehouse()

df = tdw.event('state_of_the_art_summary')
data = df['summary'].to_list()[-1]

print(data)
# Out:
# Given that no events_folder was given, the default folder will be used: /Users/jean.machado/.tinyws/events
# Results generated at 2024-03-08T17:42:14.728237 for period (2024-02-27, 2024-03-08):
#
# (0.9) Title: "Retrieval-Augmented Generation for AI-Generated Content: A Survey"
# Relevance: Relevant for staying at the forefront of AI content generation.
# Arxiv URL: http://arxiv.org/abs/2402.19473v1
#
# (0.85) Title: "Accelerating materials discovery for polymer solar cells: Data-driven insights enabled by natural language processing"
# Relevance: Relevant for insights on accelerating material discovery using NLP.
# Arxiv URL: http://arxiv.org/abs/2402.19462v1
#
# (0.8) Title: "Heavy-Tailed Class Imbalance and Why Adam Outperforms Gradient Descent on Language Models"
# Relevance: Relevant for insights on optimization techniques in ML models.
# Arxiv URL: http://arxiv.org/abs/2402.19449v1
#
# (0.75) Title: "Higher-Order Networks Representation and Learning: A Survey"
# Relevance: Relevant for advanced knowledge on network representation and learning.
# Arxiv URL: http://arxiv.org/abs/2402.19414v1
#
# (0.7) Title: "Deep Learning for Cross-Domain Data Fusion in Urban Computing: Taxonomy, Advances, and Outlook"
# Relevance: Relevant for insights on cross-domain data fusion in urban computing.
# Arxiv URL: http://arxiv.org/abs/2402.19348v1
#
# (0.65) Title: "OpenMedLM: Prompt engineering can out-perform fine-tuning in medical question-answering with open-source large language models"
# Relevance: Relevant for insights on LLMs in medical question-answering.
# Arxiv URL: http://arxiv.org/abs/2402.19371v1
#
# (0.6) Title: "A Scalable and Transferable Time Series Prediction Framework for Demand Forecasting"
# Relevance: Relevant for scalable and transferable prediction in demand forecasting.
# Arxiv URL: http://arxiv.org/abs/2402.19402v1
#
# (0.55) Title: "Machine Learning for Quantitative MR Image Reconstruction"
# Relevance: Relevant for insights on ML applications in medical imaging.
# Arxiv URL: http://arxiv.org/abs/2402.19396v1
#
# (0.5) Title: "Listening to the Noise: Blind Denoising with Gibbs Diffusion"
# Relevance: Relevant for innovative approaches in data denoising techniques.
# Arxiv URL: http://arxiv.org/abs/2402.19455v1
#
# (0.45) Title: "Panda-70M: Captioning 70M Videos with Multiple Cross-Modality Teachers"
# Relevance: Relevant for insights on video captioning with cross-modality learning.
# Arxiv URL: http://arxiv.org/abs/2402.19479v1
#
# (0.4) Title: "The All-Seeing Project V2: Towards General Relation Comprehension of the Open World"
# Relevance: Relevant for advancements in relation comprehension in open-world settings.
# Arxiv URL: http://arxiv.org/abs/2402.19474v1
#
# (0.35) Title: "Humanoid Locomotion as Next Token Prediction"
# Relevance: Relevant for innovative approaches in humanoid locomotion modeling.
# Arxiv URL: http://arxiv.org/abs/2402.19469v1
#
# (0.3) Title: "SeMoLi: What Moves Together Belongs Together"
# Relevance: Relevant for insights on motion-based learning and grouping in data science.
# Arxiv URL: http://arxiv.org/abs/2402.19463v1
#
# (0.25) Title: "Statistical Estimation in the Spiked Tensor Model via the Quantum Approximate Optimization Algorithm"
# Relevance: Relevant for quantum computing applications in statistical estimation.
# Arxiv URL: http://arxiv.org/abs/2402.19456v1
#
# (0.2) Title: "3D Gaussian Model for Animation and Texturing"
# Relevance: Relevant for advancements in 3D modeling for animation and texturing.
# Arxiv URL: http://arxiv.org/abs/2402.19441v1
# ##end

# %%
from state_of_the_art.papers import PapersComparer


from tiny_data_wharehouse.data_wharehouse import DataWharehouse
tdw = DataWharehouse()

df = tdw.event('state_of_the_art_summary')
data = df['summary'].to_list()[-1]

result = PapersComparer().extract_papers_urls(data)

df = tdw.event('state_of_the_art_summary')
data2 = df['summary'].to_list()[-4]
result2 = PapersComparer().extract_papers_urls(data2)

print("Result1", result)
print("Result2", result2)


PapersComparer().overlap_size(result, result2)
# Out:
# Given that no events_folder was given, the default folder will be used: /Users/jean.machado/.tinyws/events
# Result1 ['http://arxiv.org/abs/2402.19473v1', 'http://arxiv.org/abs/2402.19462v1', 'http://arxiv.org/abs/2402.19449v1', 'http://arxiv.org/abs/2402.19414v1', 'http://arxiv.org/abs/2402.19348v1', 'http://arxiv.org/abs/2402.19371v1', 'http://arxiv.org/abs/2402.19402v1', 'http://arxiv.org/abs/2402.19396v1', 'http://arxiv.org/abs/2402.19455v1', 'http://arxiv.org/abs/2402.19479v1', 'http://arxiv.org/abs/2402.19474v1', 'http://arxiv.org/abs/2402.19469v1', 'http://arxiv.org/abs/2402.19463v1', 'http://arxiv.org/abs/2402.19456v1', 'http://arxiv.org/abs/2402.19441v1']
# Result2 ['http://arxiv.org/abs/2402.19473v1', 'http://arxiv.org/abs/2402.19462v1', 'http://arxiv.org/abs/2402.19449v1', 'http://arxiv.org/abs/2402.19348v1', 'http://arxiv.org/abs/2402.19402v1', 'http://arxiv.org/abs/2402.19414v1', 'http://arxiv.org/abs/2402.19455v1', 'http://arxiv.org/abs/2402.19396v1', 'http://arxiv.org/abs/2402.19371v1', 'http://arxiv.org/abs/2402.19479v1', 'http://arxiv.org/abs/2402.19474v1', 'http://arxiv.org/abs/2402.19469v1', 'http://arxiv.org/abs/2402.19463v1', 'http://arxiv.org/abs/2402.19456v1', 'http://arxiv.org/abs/2402.19441v1']
# 1.0

# %%
data = df['summary'].to_list()[-5]
