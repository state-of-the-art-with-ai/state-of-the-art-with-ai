# %%
from state_of_the_art.tables.interest_table import InterestsTable


df = InterestsTable().read()
df
# Out:
#                                       name  \
# 0                                   ethics
# 1                            deep learning
# 2                  data science management
# 3                             ml lifecycle
# 4                                    mlops
# 5                                   python
# 6                 ML for combating poverty
# 7                       evaluation metrics
# 8                       my personal values
# 9                     interesting datasets
# 10                       hackdays material
# 11                               images DL
# 12                                    unix
# 13                        knowledge graphs
# 14                            andriis work
# 15   overview and taxonomy of data science
# 16             marketing machine learning
# 19                              statistics
# 20                         travel industry
# 21                        ai product guild
# 22                          rsa workstream
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Topics().len()
#
# AttributeError: 'Topics' object has no attribute 'len'
