# %%
from tiny_data_warehouse import DataWarehouse
tdw = DataWarehouse()

df = tdw.event('arxiv_papers').sort_values(by='tdw_timestamp', ascending=False)
df
# Out:
#                                                 title  \
# 0   Zero-shot LLM-guided Counterfactual Generation...
# 0   Diversity of What? On the Different Conceptual...
# 0   Comparative Analysis of Retrieval Systems in t...
# 0   Modelling Sampling Distributions of Test Stati...
# 0   Can Nuanced Language Lead to More Actionable I...
# ..                                                ...
# 0        Humanoid Locomotion as Next Token Prediction
# 0   Retrieval-Augmented Generation for AI-Generate...
# 0   The All-Seeing Project V2: Towards General Rel...
# 0   Learning a Generalized Physical Face Model Fro...
# 0   Panda-70M: Captioning 70M Videos with Multiple...
#
#                                              abstract  \
# 0   Counterfactual examples are frequently used fo...
# 0   Diversity is a commonly known principle in the...
# 0   This research paper presents a comprehensive a...
# 0   Simulation-based inference methods that featur...
# 0   Relevant language describing trends in data ca...
# ..                                                ...
# 0   We cast real-world humanoid control as a next ...
# 0   The development of Artificial Intelligence Gen...
# 0   We present the All-Seeing Project V2: a new mo...
# 0   Physically-based simulation is a powerful appr...
# 0   The quality of the data and annotation upper-b...
#
#                                    url                 published  \
# 0   https://arxiv.org/abs/2405.04793v1 2024-05-08 03:57:45+00:00
# 0   https://arxiv.org/abs/2405.02026v1 2024-05-03 11:58:03+00:00
# 0   https://arxiv.org/abs/2405.02048v1 2024-05-03 12:30:01+00:00
# 0   https://arxiv.org/abs/2405.02488v1 2024-05-03 21:34:12+00:00
# 0   https://arxiv.org/abs/2405.02763v1 2024-05-04 21:59:30+00:00
# ..                                 ...                       ...
# 0    http://arxiv.org/abs/2402.19469v1 2024-02-29 18:57:37+00:00
# 0    http://arxiv.org/abs/2402.19473v1 2024-02-29 18:59:01+00:00
# 0    http://arxiv.org/abs/2402.19474v1 2024-02-29 18:59:17+00:00
# 0    http://arxiv.org/abs/2402.19477v1 2024-02-29 18:59:31+00:00
# 0    http://arxiv.org/abs/2402.19479v1 2024-02-29 18:59:50+00:00
#
#                 tdw_timestamp
# 0  2024-05-11 22:05:07.798903
# 0  2024-05-11 22:00:38.101411
# 0  2024-05-11 21:57:03.639308
# 0  2024-05-11 21:49:53.279908
# 0  2024-05-11 21:28:53.502375
# ..                        ...
# 0  2024-03-02 15:20:28.565966
# 0  2024-03-02 15:20:28.563475
# 0  2024-03-02 15:20:28.560878
# 0  2024-03-02 15:20:28.547171
# 0  2024-03-02 15:20:28.528195
#
# [21202 rows x 5 columns]

# %% [markdown]
# ## Number of papers per day

# %%
import pandas as pd
def plot_days(n_days):
    new_df = df.groupby(by=df.published.dt.date).agg({'published': 'count'})
    new_df['date'] = new_df.index
    new_df['published_count'] = new_df['published']


    NUM_OF_DAYS = 30
    new_df.reset_index(drop=True, inplace=True)
    new_df = new_df.sort_values(by='date', ascending=False).head(n_days)
    new_df['date'] = pd.to_datetime(new_df['date'])
    new_df.reset_index(drop=True, inplace=True)
    new_df.plot(x='date', y='published')
    
plot_days(10)

# %%
plot_days(60)
