# %%
from state_of_the_art.config import config
tdw = config.get_datawarehouse()
df = tdw.event('arxiv_papers')

print(len(df.index))
df
# Out:
# 24022
#                                                 title  \
# 0   Panda-70M: Captioning 70M Videos with Multiple...
# 0   Learning a Generalized Physical Face Model Fro...
# 0   The All-Seeing Project V2: Towards General Rel...
# 0   Retrieval-Augmented Generation for AI-Generate...
# 0        Humanoid Locomotion as Next Token Prediction
# ..                                                ...
# 0   How To Save A World: The Go-Along Interview as...
# 0   Single-ensemble multilevel Monte Carlo for dis...
# 0   Wukong: Towards a Scaling Law for Large-Scale ...
# 0   Wukong: Towards a Scaling Law for Large-Scale ...
# 0                     KAN: Kolmogorov-Arnold Networks
#
#                                              abstract  \
# 0   The quality of the data and annotation upper-b...
# 0   Physically-based simulation is a powerful appr...
# 0   We present the All-Seeing Project V2: a new mo...
# 0   The development of Artificial Intelligence Gen...
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 tdw.write_event('arxiv_papers', {'url': 'http://arxiv.org/abs/2402.19479v1'}, dry_run=True)
#
# File ~/projects/tiny-data-warehouse/tiny_data_warehouse/data_warehouse.py:46, in DataWarehouse.write_event(self, event_name, event_data, verbose, dry_run)
#      44         # test if in existing_data there is a duplicated value
#      45         if possible_duplicated_value in existing_data[check_column_name].values:
# ---> 46             raise ValueError(f"A duplicated value {event_data[check_column_name]} for key {check_column_name} was found in the event {event_name}")
#      48     df = pd.concat([existing_data, new_df])
#      50 if not dry_run:
#
# ValueError: A duplicated value http://arxiv.org/abs/2402.19479v1 for key url was found in the event arxiv_papers

# %%
new = df.drop_duplicates(subset=['url'], keep='last')

print(len(new.index))
new
# Out:
# 24022
#                                                 title  \
# 0   Panda-70M: Captioning 70M Videos with Multiple...
# 0   Learning a Generalized Physical Face Model Fro...
# 0   The All-Seeing Project V2: Towards General Rel...
# 0   Retrieval-Augmented Generation for AI-Generate...
# 0        Humanoid Locomotion as Next Token Prediction
# ..                                                ...
# 0   How To Save A World: The Go-Along Interview as...
# 0   Single-ensemble multilevel Monte Carlo for dis...
# 0   Wukong: Towards a Scaling Law for Large-Scale ...
# 0   Wukong: Towards a Scaling Law for Large-Scale ...
# 0                     KAN: Kolmogorov-Arnold Networks
#
#                                              abstract  \
# 0   The quality of the data and annotation upper-b...
# 0   Physically-based simulation is a powerful appr...
# 0   We present the All-Seeing Project V2: a new mo...
# 0   The development of Artificial Intelligence Gen...
# ...

# %%
len(new.index)

#tdw.replace_df('arxiv_papers', new, dry_run=False)

# %%
from state_of_the_art.paper.paper import ArxivPaper
from state_of_the_art.config import config

tdw = config.get_datawarehouse()
df = tdw.event('arxiv_papers')

df['url'] = df['url'].map(lambda x: ArxivPaper._remove_versions_from_url(x))

#df
print(len(df.index))

#tdw.replace_df('arxiv_papers', df, dry_run=False)
# Out:
# 24022

# %%
from state_of_the_art.paper.paper import ArxivPaper

ArxivPaper(url='https://arxiv.org/abs/2403.18969v1').abstract_url
# Out:
# 'https://arxiv.org/abs/2403.18969'
