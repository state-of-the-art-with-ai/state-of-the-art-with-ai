# %%
from tiny_data_warehouse import DataWarehouse
tdw = DataWarehouse()
df = tdw.event('sota_paper_insight')
df
# Out:
#                                              insights  \
# 0   Title: A "Distance Matters" Paradox: Facilitat...
# 0   Title: What Does Artificial Life Tell Us About...
# 0   Title: How Good Is NLP? A Sober Look at NLP Ta...
# 0   Title: Empowering Africa: An In-depth Explorat...
# 0   Title: Replica Wormholes and Entanglement Isla...
# ..                                                ...
# 0   Title: HiLo: A Learning Framework for Generali...
# 0   Title: SCENE: Evaluating Explainable AI Techni...
# 0   Title: MM-Forecast: A Multimodal Approach to T...
# 0   Title: Survey on AI Ethics: A Socio-technical ...
# 0   Title: A Comprehensive Survey of Evaluation Te...
#
#                 tdw_timestamp                        abstract_url  \
# 0  2024-05-26 12:55:56.730609  https://arxiv.org/abs/2202.02484v1
# 0  2024-05-26 12:25:41.858861     https://arxiv.org/abs/0906.2824
# 0  2024-05-26 12:23:04.066965    https://arxiv.org/abs/2106.02359
# ...
