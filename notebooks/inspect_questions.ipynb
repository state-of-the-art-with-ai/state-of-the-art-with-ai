# %%
from state_of_the_art.paper.questions_table import QuestionsTable


QuestionsTable().read()
# Out:
#   short_version                                           question order  \
# 0   Institution  Which institution or insitutions  published th...  None
# 1    Conference      In which conference was this paper published?  None
# 2          Deep  Return a summary on explaining in an clear way...  None
# 3        Unique                   What is unique about this paper?  None
# 4     Weakeness                 What are weakenesses of the paper?  None
# 5     Resources  Rturns further resources recommendations from ...  None
# 6   Definitions  define core terms in the paper use analogies i...  None
#
#   min_items max_items
# 0      None      None
# 1      None      None
# 2      None      None
# 3      None      None
# 4         3      None
# 5         3      None
# 6         4      None
