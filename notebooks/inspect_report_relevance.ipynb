# %%
import json
from state_of_the_art.tables.recommendations_history_table import RecommendationsHistoryTable


last = RecommendationsHistoryTable().last().to_dict()


json_data =json.loads(last['recommended_papers'].replace("'", '"'))
json_data
# Out:
# {'elasticity': {'papers': ['http://arxiv.org/abs/2408.16842',
#    'http://arxiv.org/abs/2408.17233',
#    'http://arxiv.org/abs/2408.17370',
#    'http://arxiv.org/abs/2408.17209',
#    'http://arxiv.org/abs/2408.17005',
#    'http://arxiv.org/abs/2408.17235',
#    'http://arxiv.org/abs/2408.17383',
#    'http://arxiv.org/abs/2408.17171',
#    'http://arxiv.org/abs/2408.17380',
#    'http://arxiv.org/abs/2408.17051'],
#   'papers_objects': {'http://arxiv.org/abs/2408.16842': {'score': 0.30379632115364075},
#    'http://arxiv.org/abs/2408.17233': {'score': 0.2895631492137909},
#    'http://arxiv.org/abs/2408.17370': {'score': 0.20214693248271942},
#    'http://arxiv.org/abs/2408.17209': {'score': 0.19764770567417145},
#    'http://arxiv.org/abs/2408.17005': {'score': 0.19588281214237213},
#    'http://arxiv.org/abs/2408.17235': {'score': 0.18961258232593536},
#    'http://arxiv.org/abs/2408.17383': {'score': 0.1883830577135086},
# ...
